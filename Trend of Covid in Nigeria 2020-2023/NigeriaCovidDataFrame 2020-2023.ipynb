# %%
import pandas as pd 
from matplotlib import pyplot as plt 
import datetime as dt
import numpy as np

# %%
df=pd.read_csv('Nigeria Covid update.csv')

# %%
#Creating a Copy
Nigeria_Data=df.copy()

# %%
Nigeria_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1273 entries, 0 to 1272
# Data columns (total 69 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Unnamed: 0                                  1273 non-null   int64
#  1   iso_code                                    1273 non-null   object
#  2   continent                                   1273 non-null   object
#  3   location                                    1273 non-null   object
#  4   date                                        1273 non-null   object
#  5   population                                  1273 non-null   int64
#  6   new_cases                                   1273 non-null   float64
#  7   new_cases_smoothed                          1268 non-null   float64
#  8   total_deaths                                1193 non-null   float64
#  9   new_deaths                                  1273 non-null   float64
#  10  new_deaths_smoothed                         1268 non-null   float64
#  11  total_cases_per_million                     1216 non-null   float64
#  12  new_cases_per_million                       1273 non-null   float64
#  13  new_cases_smoothed_per_million              1268 non-null   float64
#  14  total_deaths_per_million                    1193 non-null   float64
#  15  new_deaths_per_million                      1273 non-null   float64
#  16  new_deaths_smoothed_per_million             1268 non-null   float64
#  17  reproduction_rate                           1009 non-null   float64
#  18  icu_patients                                0 non-null      float64
#  19  icu_patients_per_million                    0 non-null      float64
#  20  hosp_patients                               0 non-null      float64
#  21  hosp_patients_per_million                   0 non-null      float64
#  22  weekly_icu_admissions                       0 non-null      float64
#  23  weekly_icu_admissions_per_million           0 non-null      float64
#  24  weekly_hosp_admissions                      0 non-null      float64
#  25  weekly_hosp_admissions_per_million          0 non-null      float64
#  26  total_tests                                 287 non-null    float64
#  27  new_tests                                   162 non-null    float64
#  28  total_tests_per_thousand                    287 non-null    float64
#  29  new_tests_per_thousand                      162 non-null    float64
#  30  new_tests_smoothed                          799 non-null    float64
#  31  new_tests_smoothed_per_thousand             799 non-null    float64
#  32  positive_rate                               798 non-null    float64
#  33  tests_per_case                              798 non-null    float64
#  34  tests_units                                 806 non-null    object
#  35  total_vaccinations                          132 non-null    float64
#  36  people_vaccinated                           132 non-null    float64
#  37  people_fully_vaccinated                     88 non-null     float64
#  38  total_boosters                              23 non-null     float64
#  39  new_vaccinations                            49 non-null     float64
#  40  new_vaccinations_smoothed                   745 non-null    float64
#  41  total_vaccinations_per_hundred              132 non-null    float64
#  42  people_vaccinated_per_hundred               132 non-null    float64
#  43  people_fully_vaccinated_per_hundred         88 non-null     float64
#  44  total_boosters_per_hundred                  23 non-null     float64
#  45  new_vaccinations_smoothed_per_million       745 non-null    float64
#  46  new_people_vaccinated_smoothed              745 non-null    float64
#  47  new_people_vaccinated_smoothed_per_hundred  745 non-null    float64
#  48  stringency_index                            1094 non-null   float64
#  49  population_density                          1273 non-null   float64
#  50  median_age                                  1273 non-null   float64
#  51  aged_65_older                               1273 non-null   float64
#  52  aged_70_older                               1273 non-null   float64
#  53  gdp_per_capita                              1273 non-null   float64
#  54  extreme_poverty                             0 non-null      float64
#  55  cardiovasc_death_rate                       1273 non-null   float64
#  56  diabetes_prevalence                         1273 non-null   float64
#  57  female_smokers                              1273 non-null   float64
#  58  male_smokers                                1273 non-null   float64
#  59  handwashing_facilities                      1273 non-null   float64
#  60  hospital_beds_per_thousand                  0 non-null      float64
#  61  life_expectancy                             1273 non-null   float64
#  62  human_development_index                     1273 non-null   float64
#  63  Unnamed: 62                                 0 non-null      float64
#  64  excess_mortality_cumulative_absolute        0 non-null      float64
#  65  excess_mortality_cumulative                 0 non-null      float64
#  66  excess_mortality                            0 non-null      float64
#  67  excess_mortality_cumulative_per_million     0 non-null      float64
#  68  months                                      1273 non-null   object
# dtypes: float64(61), int64(2), object(6)
# memory usage: 686.4+ KB

# %%
#Filtering important Column
Nigeria_Data=Nigeria_Data.loc[:,[
                                'date','new_cases','new_cases_smoothed',	'total_deaths',
                                'new_deaths','new_deaths_smoothed',
                                'total_cases_per_million','new_cases_per_million',
                                'new_cases_smoothed_per_million','total_deaths_per_million',
                                'new_deaths_per_million','new_deaths_smoothed_per_million','months'
]]

# %%
Nigeria_Data['date']
# Out:
# 0       2020-01-03
# 1       2020-01-04
# 2       2020-01-05
# 3       2020-01-06
# 4       2020-01-07
#            ...
# 1268    2023-06-24
# 1269    2023-06-25
# 1270    2023-06-26
# 1271    2023-06-27
# 1272    2023-06-28
# Name: date, Length: 1273, dtype: object

# %%
#cleaing date
Nigeria_Data['date']=pd.to_datetime(Nigeria_Data['date'])

# %%
Nigeria_Data['year']=Nigeria_Data['date'].dt.year

# %%
Years_Count=Nigeria_Data['year'].unique()
Years_Count.tolist()
# Out:
# [2020, 2021, 2022, 2023]

# %%
YearlyTrend=(
    Nigeria_Data.groupby('year')
    ['new_cases'].sum().reset_index(name='Total_new_Cases')
    
)
YearlyTrend
# Out:
#    year  Total_new_Cases
# 0  2020          86576.0
# 1  2021         154937.0
# 2  2022          24937.0
# 3  2023            225.0

# %% [markdown]
# __YEARLY TREND OF COVID 2021-2023__

# %%
YearlyTrend.plot(kind='line',x='year',y='Total_new_Cases',figsize=(10,6))
plt.tight_layout
plt.grid(axis='y',linestyle='--',alpha=0.2)
plt.title("COVID TREND IN NIGERIA 2020-2023")
# Out:
# Text(0.5, 1.0, 'COVID TREND IN NIGERIA 2020-2023')

# %%
#Data per Year
Trend_Per_Year={
    year:Nigeria_Data[Nigeria_Data['year']==year] for year in Years_Count
}

Covid_2020=Trend_Per_Year[2020]
Covid_2021=Trend_Per_Year[2021]
Covid_2022=Trend_Per_Year[2022]
Covid_2023=Trend_Per_Year[2023]

# %%
def grouped_months(yearData):
    monthOrder=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
    yearData=yearData.groupby('months')['new_cases'].sum().reset_index(name='Count')
    #pivot_table(columns='months',values='new_cases',aggfunc='sum')
    #yearData=yearData.reindex(columns=monthOrder,fill_value=0)
    yearData=yearData.set_index('months').reindex(monthOrder,fill_value=0).reset_index()
    return yearData

# %%
Covid_2020_MonthlyTrend=grouped_months(Covid_2020)
Covid_2021_MonthlyTrend=grouped_months(Covid_2021)
Covid_2022_MonthlyTrend=grouped_months(Covid_2022)
Covid_2023_MonthlyTrend=grouped_months(Covid_2023)
Covid_2023_MonthlyTrend
# Out:
#    months  Count
# 0     Jan   13.0
# 1     Feb  135.0
# 2     Mar   62.0
# 3     Apr   15.0
# 4     May    0.0
# 5     Jun    0.0
# 6     Jul    0.0
# 7     Aug    0.0
# 8     Sep    0.0
# 9     Oct    0.0
# 10    Nov    0.0
# 11    Dec    0.0

# %%
def plot_months(groupedData,year):
    groupedData=[
            groupedData.plot(kind='line',marker='*',figsize=(10,5),x='months',y='Count'),
            
            plt.title(f'MONTHLY COVID -19 NEW CASES IN {year}'),
            plt.xlabel('Month'),
            plt.ylabel('New Cases'),
            plt.grid(True, linestyle='--'),
            plt.xticks(rotation=45),
            plt.tight_layout(),
            plt.show()
        ]

# %%
Covid_2020_MonthlyTrend
# Out:
#    months    Count
# 0     Jan      0.0
# 1     Feb      1.0
# 2     Mar    135.0
# 3     Apr   1592.0
# 4     May   8127.0
# 5     Jun  15278.0
# 6     Jul  17556.0
# 7     Aug  11176.0
# 8     Sep   4782.0
# 9     Oct   4044.0
# 10    Nov   4721.0
# 11    Dec  19164.0

# %% [markdown]
# __COVID TREND FOR 2020__

# %%
plot_2020=plot_months(Covid_2020_MonthlyTrend,2020)

# %% [markdown]
# __COVID TREND FOR 2021__

# %%
plot_2021=plot_months(Covid_2021_MonthlyTrend,2021)

# %% [markdown]
# __COVID TREND FOR 2022__

# %%
plot_2022=plot_months(Covid_2022_MonthlyTrend,2022)

# %% [markdown]
# __COVID TREND FOR 2023__

# %%
plot_2023=plot_months(Covid_2023_MonthlyTrend,2023)

# %%
cases_2020 = grouped_months(Covid_2020)['Count'].tolist()
cases_2021 = grouped_months(Covid_2021)['Count'].tolist()
cases_2022 = grouped_months(Covid_2022)['Count'].tolist()
cases_2023 = grouped_months(Covid_2023)['Count'].tolist()

# %%
month=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
data={
    'Year':[],
    'months':[],
    'New_Cases':[]
}

# %% [markdown]
# __COMPILED TREND__

# %%
for year, values in zip(
    [2020,2021,2022,2023], [cases_2020,cases_2021,cases_2022,cases_2023]
):
    data['Year'].extend([year]*len(month))
    data['months'].extend(month)
    data['New_Cases'].extend(values)

compiledData=pd.DataFrame(data)

# %%
#compiledTrend=compiledData.pivot_table(columns='Year',index='months',values='New_Cases')
month_order = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
compiledData['months'] = pd.Categorical(compiledData['months'], categories=month_order, ordered=True)
compiledData = compiledData.sort_values('months')

# %%
compiledTrend = compiledData.pivot_table(columns='Year', 
                                         index='months',
                                         values='New_Cases',
                                         fill_value=0,
                                         observed=False
                                        )

compiledTrendChart = compiledTrend.plot(kind='line', marker='*', figsize=(10, 5))
plt.title('TREND OF NEW CASES OF COVID 2020–2023')
plt.xlabel('Month')
plt.ylabel('New Cases')
plt.grid(True, linestyle='--')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
